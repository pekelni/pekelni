# %% [markdown]
# Задайте змінні для розміру поля, знаків (хрестик, нулик) і ігрове поле (двовимірний масив). Задайте послідовність ходів у будь-якому порядку за допомогою двох вкладених `for` циклів. Хід задається кортежем або списком із двох чисел що задають координати (рядок і колонку) клітинки.
#
# Перемішайте послідовність ходів щоб вона була випадковою. Далі для кожного номеру ходу (0, 1, 2, ..., 8) виберіть відповідний хід із випадкової послідовності ходів і відповідний знак, заповніть відповідну клітинку ігрового поля і виведіть ігрове поле на екран.
