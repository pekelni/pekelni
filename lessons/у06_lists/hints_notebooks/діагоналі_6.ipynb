# %% [markdown]
# У цьому варіанті рішення спершу відбувається робота над внутрішньою презентацією дошки (двувимірний список із логічними значенням `True`, `False`), і лише потім внутрішня презентація виводиться на екран. Це дуже практичний і реалістичний підхід, тому що допомогає розділити модель (презентація дошки у пам'яті) і "вид" (презентація на екрані, view). Таке розділення корисне бо візуальних презентацій може бути багато різних: у консолі, на веб сторінці, на мобільному телефоні і так далі. І часто програма має підтримувати кілька візуальних презентацій для однієї логічної внутрішньої презентації.
#
# Але уявімо що цього разу нас такі роздуми не цікавлять. Спробуйти скоротити програму повністю позбувшись змінних `ПУСТИЙ_РЯДОК` та `дошка` і одразу виводьте необхідну інформацію на екран (у консоль), а не у внутрішню презентацію (двовимірний список).

# %% [markdown]
# Внизу я скопіював варіант рішення який я пропоную ще більше скоротити.

# %%
РОЗМІР_ДОШКИ = 8

ПУСТИЙ_РЯДОК = list()
for i in range(РОЗМІР_ДОШКИ):
    ПУСТИЙ_РЯДОК.append(False)

МЕТА_ПАРАМЕТРИ = (
    ('різниця', range(1 - РОЗМІР_ДОШКИ, РОЗМІР_ДОШКИ)),
    ('сума', range(2 * РОЗМІР_ДОШКИ - 1)),
)

for тип_діагоналі, діапазон in МЕТА_ПАРАМЕТРИ:
    for параметр_діагоналі in діапазон:
        print()
        дошка = list()
        for i in range(РОЗМІР_ДОШКИ):
            дошка.append(list(ПУСТИЙ_РЯДОК))

        for i in range(РОЗМІР_ДОШКИ):
            for j in range(РОЗМІР_ДОШКИ):
                if тип_діагоналі == 'сума':
                    if i + j == параметр_діагоналі:
                        дошка[i][j] = True
                elif тип_діагоналі == 'різниця':
                    if i - j == параметр_діагоналі:
                        дошка[i][j] = True

        for рядок in дошка:
            print(end='|')
            for клітина in рядок:
                символ = 'D' if клітина else ' '
                print(символ, end='|')
            print()
# Out:
# | | | | | | | |D|
# | | | | | | | | |
# | | | | | | | | |
# | | | | | | | | |
# | | | | | | | | |
# | | | | | | | | |
# | | | | | | | | |
# | | | | | | | | |
#
# | | | | | | |D| |
# | | | | | | | |D|
# | | | | | | | | |
# | | | | | | | | |
# | | | | | | | | |
# | | | | | | | | |
# | | | | | | | | |
# | | | | | | | | |
#
# | | | | | |D| | |
# | | | | | | |D| |
# | | | | | | | |D|
# | | | | | | | | |
# | | | | | | | | |
# | | | | | | | | |
# | | | | | | | | |
# | | | | | | | | |
#
# | | | | |D| | | |
# | | | | | |D| | |
# | | | | | | |D| |
# | | | | | | | |D|
# | | | | | | | | |
# | | | | | | | | |
# | | | | | | | | |
# | | | | | | | | |
#
# | | | |D| | | | |
# | | | | |D| | | |
# | | | | | |D| | |
# | | | | | | |D| |
# | | | | | | | |D|
# | | | | | | | | |
# | | | | | | | | |
# | | | | | | | | |
#
# | | |D| | | | | |
# | | | |D| | | | |
# | | | | |D| | | |
# | | | | | |D| | |
# | | | | | | |D| |
# | | | | | | | |D|
# | | | | | | | | |
# | | | | | | | | |
#
# | |D| | | | | | |
# ...
